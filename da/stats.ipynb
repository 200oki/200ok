# %% [markdown]
# # 주민 통계에 사용되는 컬럼만 골라내기!

# %%
import pandas as pd
import numpy as np

# %%
from os import path
import os
from pprint import pprint

import pandas as pd
import numpy as np

# %%
df = pd.read_excel('./datasets/villagers.xlsx')
df.head()
# Out:
#    Unnamed: 0     Name                                    Icon Image  \
# 0           0  Admiral  https://acnhcdn.com/latest/NpcIcon/brd06.png
# 1           1  Agent S  https://acnhcdn.com/latest/NpcIcon/squ05.png
# 2           2    Agnes  https://acnhcdn.com/latest/NpcIcon/pig17.png
# 3           3       Al  https://acnhcdn.com/latest/NpcIcon/gor08.png
# 4           4  Alfonso  https://acnhcdn.com/latest/NpcIcon/crd00.png
#
#                                          Photo Image  \
# 0  https://acnhcdn.com/latest/NpcBromide/NpcNmlBr...
# 1  https://acnhcdn.com/latest/NpcBromide/NpcNmlSq...
# 2  https://acnhcdn.com/latest/NpcBromide/NpcNmlPi...
# 3  https://acnhcdn.com/latest/NpcBromide/NpcNmlGo...
# 4  https://acnhcdn.com/latest/NpcBromide/NpcNmlCr...
#
#                                          House Image    Species  Gender  \
# 0  https://acnhcdn.com/drivesync/render/houses/br...       Bird    Male
# 1  https://acnhcdn.com/drivesync/render/houses/sq...   Squirrel  Female
# ...

# %% [markdown]
# ## 사용되는 컬럼
# - 성별
# - 종
# - 성격
# - 취미
# - 스타일

# %%
characters_stats = df[['Gender', 'Species', 'Personality', 'Hobby', 'Style 1']]
characters_stats.head()
# Out:
#    Gender    Species Personality    Hobby Style 1
# 0    Male       Bird      Cranky   Nature    Cool
# 1  Female   Squirrel       Peppy  Fitness  Active
# 2  Female        Pig  Big Sister     Play  Simple
# 3    Male    Gorilla        Lazy  Fitness  Active
# 4    Male  Alligator        Lazy     Play  Simple

# %%
characters_stats.to_excel('./datasets/characters_stats.xlsx')
