# %% [markdown]
# # charactors.json 기존 데이터 오류 수정

# %%
import ast
from datetime import date
import json
from pprint import pprint

import numpy as np
import pandas as pd

# %%
chars = pd.read_excel('./datasets/characters.xlsx')
chars.head()
# Out:
#    Unnamed: 0       id  special  name_en name_ko  \
# 0           0  admiral    False  Admiral      일섭
# 1           1   agents    False  Agent S      2호
# 2           2    agnes    False    Agnes    아그네스
# 3           3       al    False       Al      우락
# 4           4  alfonso    False  Alfonso    알베르트
#
#                                      image_icon  \
# 0  https://acnhcdn.com/latest/NpcIcon/brd06.png
# 1  https://acnhcdn.com/latest/NpcIcon/squ05.png
# 2  https://acnhcdn.com/latest/NpcIcon/pig17.png
# 3  https://acnhcdn.com/latest/NpcIcon/gor08.png
# 4  https://acnhcdn.com/latest/NpcIcon/crd00.png
#
#                                          image_photo  \
# 0  https://acnhcdn.com/latest/NpcBromide/NpcNmlBr...
# 1  https://acnhcdn.com/latest/NpcBromide/NpcNmlSq...
# 2  https://acnhcdn.com/latest/NpcBromide/NpcNmlPi...
# 3  https://acnhcdn.com/latest/NpcBromide/NpcNmlGo...
# 4  https://acnhcdn.com/latest/NpcBromide/NpcNmlCr...
#
# ...

# %%
chars = chars.drop('Unnamed: 0', axis=1)
chars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452 entries, 0 to 451
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   451 non-null    object
#  1   special              452 non-null    bool
#  2   name_en              452 non-null    object
#  3   name_ko              452 non-null    object
#  4   image_icon           452 non-null    object
#  5   image_photo          452 non-null    object
#  6   image_house          391 non-null    object
#  7   species              391 non-null    object
#  8   gender               452 non-null    object
#  9   gender_asia          452 non-null    object
#  10  birthday             452 non-null    object
#  11  birthday_month       452 non-null    int64
#  12  birthday_day         452 non-null    int64
#  13  personality          391 non-null    object
#  14  personality_subtype  391 non-null    object
# ...

# %%
chars.loc[:, ['colors', 'styles']]
# Out:
#               colors          styles
# 0     ['검정색', '파랑색']           ['쿨']
# 1     ['검정색', '파랑색']   ['심플', '액티브']
# 2     ['하양색', '핑크색']  ['심플', '엘레강스']
# 3     ['하양색', '빨강색']         ['액티브']
# 4     ['빨강색', '파랑색']          ['심플']
# ..               ...             ...
# 447   ['초록색', '검정색']    ['액티브', '쿨']
# 448  ['오렌지색', '노랑색']   ['엘레강스', '쿨']
# 449    ['보라색', '회색']    ['고져스', '쿨']
# 450              NaN             NaN
# 451   ['파랑색', '노랑색']    ['심플', '큐트']
#
# [452 rows x 2 columns]

# %%
chars['colors'] = chars['colors'].apply(
  lambda expr: ast.literal_eval(expr) if type(expr) == str else expr
)
chars['styles'] = chars['styles'].apply(
  lambda expr: ast.literal_eval(expr) if type(expr) == str else expr
)

# %%
chars.loc[371, 'image_photo'] = 'https://acnhcdn.com/latest/NpcBromide/NpcSpHgs.png'

# %%
chars.loc[371, 'image_photo']
# Out:
# 'https://acnhcdn.com/latest/NpcBromide/NpcSpHgs.png'

# %% [markdown]
# ## 컬럼 정리
#
# 하는 김에 합니다.
#
# json에선 의미가 없지만 엑셀에선 정리가 좀 돼있으면 편합니다

# %%
# chars.columns = sorted(chars.columns)
pprint(sorted(list(chars.columns)))
# Out:
# ['birthday',
#  'birthday_day',
#  'birthday_month',
#  'catchphrase',
#  'colors',
#  'favorite_saying',
#  'favorite_song',
#  'gender',
#  'gender_asia',
#  'hobby',
#  'id',
#  'image_house',
#  'image_icon',
#  'image_photo',
#  'name_en',
#  'name_ko',
#  'personality',
#  'personality_subtype',
#  'rank',
#  'special',
#  'species',
#  'styles',
#  'tier']

# %%
chars = chars[[
  'id',
  'name_ko',
  'name_en',
  'special',
  'gender',
  'gender_asia',
  'species',
  'birthday',
  'birthday_month',
  'birthday_day',
  'hobby',
  'personality',
  'personality_subtype',
  'colors',
  'styles',
  'tier',
  'rank',
  'catchphrase',
  'favorite_saying',
  'favorite_song',
  'image_house',
  'image_icon',
  'image_photo',
]]

# %%
chars.head()
# Out:
#         id name_ko  name_en  special  gender gender_asia    species birthday  \
# 0  admiral      일섭  Admiral    False    Male        Male       Bird    01-27
# 1   agents      2호  Agent S    False  Female      Female   Squirrel    07-02
# 2    agnes    아그네스    Agnes    False  Female      Female        Pig    04-21
# 3       al      우락       Al    False    Male        Male    Gorilla    10-18
# 4  alfonso    알베르트  Alfonso    False    Male        Male  Alligator    06-09
#
#    birthday_month  birthday_day  ...      colors      styles tier  rank  \
# 0               1            27  ...  [검정색, 파랑색]         [쿨]  6.0  89.0
# 1               7             2  ...  [검정색, 파랑색]   [심플, 액티브]  6.0  45.0
# 2               4            21  ...  [하양색, 핑크색]  [심플, 엘레강스]  4.0  26.0
# 3              10            18  ...  [하양색, 빨강색]       [액티브]  6.0  19.0
# 4               6             9  ...  [빨강색, 파랑색]        [심플]  6.0   6.0
#
# ...

# %%
chars['species'].head()
# Out:
# 0         Bird
# 1     Squirrel
# 2          Pig
# 3      Gorilla
# 4    Alligator
# Name: species, dtype: object

# %% [markdown]
# ## species 번역
#
# 다른 팀원이 해놨다고 하니까 그 파일을 좀 찾아보고 오겠습니다.

# %%
trans_species = dict(
    zip(
        [
            'Bird',
            'Squirrel',
            'Pig',
            'Gorilla',
            'Alligator',
            'Koala',
            'Eagle',
            'Anteater',
            'Bull',
            'Mouse',
            'Cat',
            'Horse',
            'Hamster',
            'Kangaroo',
            'Wolf',
            'Penguin',
            'Chicken',
            'Elephant',
            'Sheep',
            'Deer',
            'Tiger',
            'Cub',
            'Dog',
            'Bear',
            'Hippo',
            'Duck',
            'Goat',
            'Ostrich',
            'Rabbit',
            'Lion',
            'Frog',
            'Monkey',
            'Rhino',
            'Octopus',
            'Cow'
        ],
        [
            '새',
            '다람쥐',
            '돼지',
            '고릴라',
            '악어',
            '코알라',
            '독수리',
            '개미핥기',
            '수소',
            '쥐',
            '고양이',
            '말',
            '햄스터',
            '캥거루',
            '늑대',
            '펭귄',
            '닭',
            '코끼리',
            '양',
            '사슴',
            '호랑이',
            '꼬마곰',
            '개',
            '곰',
            '하마',
            '오리',
            '염소',
            '타조',
            '토끼',
            '사자',
            '개구리',
            '원숭이',
            '코뿔소',
            '문어',
            '암소'
        ]
    )
)

# %%
len(trans_species)
# Out:
# 35

# %%
def translate(ref, val):
    return ref.get(val)

# %%
chars['species'] = chars['species'].apply(
  lambda v: translate(trans_species, v)
)

# %%
chars['species'].head()
# Out:
# 0      새
# 1    다람쥐
# 2     돼지
# 3    고릴라
# 4     악어
# Name: species, dtype: object

# %% [markdown]
# ## nan 고치기
#
# 이름이 nan인 녀석이 있습니다.

# %%
chars[chars['id'].isnull()]
# Out:
#       id name_ko name_en  special  gender gender_asia species birthday  \
# 284  NaN      순이     Nan    False  Female      Female      염소    08-24
#
#      birthday_month  birthday_day  ...       colors      styles tier  rank  \
# 284               8            24  ...  [오렌지색, 노랑색]  [심플, 엘레강스]  4.0  18.0
#
#     catchphrase       favorite_saying  favorite_song  \
# 284         kid  Nanny-nanny boo-boo!     K.K. Étude
#
#                                            image_house  \
# 284  https://acnhcdn.com/drivesync/render/houses/go...
#
#                                        image_icon  \
# 284  https://acnhcdn.com/latest/NpcIcon/goa01.png
#
#                                            image_photo
# 284  https://acnhcdn.com/latest/NpcBromide/NpcNmlGo...
#
# [1 rows x 23 columns]

# %%
chars.loc[284, 'id'] = 'nan'

# %%
chars[chars['id'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, name_ko, name_en, special, gender, gender_asia, species, birthday, birthday_month, birthday_day, hobby, personality, personality_subtype, colors, styles, tier, rank, catchphrase, favorite_saying, favorite_song, image_house, image_icon, image_photo]
# Index: []
#
# [0 rows x 23 columns]

# %% [markdown]
# ## 인덱스 정리

# %%
chars.index = chars['id']
chars = chars.drop('id', axis=1)

# %%
chars.head()
# Out:
#         name_ko  name_en  special  gender gender_asia species birthday  \
# id
# admiral      일섭  Admiral    False    Male        Male       새    01-27
# agents       2호  Agent S    False  Female      Female     다람쥐    07-02
# agnes      아그네스    Agnes    False  Female      Female      돼지    04-21
# al           우락       Al    False    Male        Male     고릴라    10-18
# alfonso    알베르트  Alfonso    False    Male        Male      악어    06-09
#
#          birthday_month  birthday_day hobby  ...      colors      styles tier  \
# id                                           ...
# admiral               1            27    자연  ...  [검정색, 파랑색]         [쿨]  6.0
# agents                7             2    운동  ...  [검정색, 파랑색]   [심플, 액티브]  6.0
# agnes                 4            21    놀이  ...  [하양색, 핑크색]  [심플, 엘레강스]  4.0
# al                   10            18    운동  ...  [하양색, 빨강색]       [액티브]  6.0
# alfonso               6             9    놀이  ...  [빨강색, 파랑색]        [심플]  6.0
#
# ...

# %% [markdown]
# ## `birthday_yday` 삽입
#
# 윤년이라 가정한 yday를 집어 넣습니다.

# %%
chars.head()
# Out:
#         name_ko  name_en  special  gender gender_asia species birthday  \
# id
# admiral      일섭  Admiral    False    Male        Male       새    01-27
# agents       2호  Agent S    False  Female      Female     다람쥐    07-02
# agnes      아그네스    Agnes    False  Female      Female      돼지    04-21
# al           우락       Al    False    Male        Male     고릴라    10-18
# alfonso    알베르트  Alfonso    False    Male        Male      악어    06-09
#
#          birthday_month  birthday_day hobby  ...      colors      styles tier  \
# id                                           ...
# admiral               1            27    자연  ...  [검정색, 파랑색]         [쿨]  6.0
# agents                7             2    운동  ...  [검정색, 파랑색]   [심플, 액티브]  6.0
# agnes                 4            21    놀이  ...  [하양색, 핑크색]  [심플, 엘레강스]  4.0
# al                   10            18    운동  ...  [하양색, 빨강색]       [액티브]  6.0
# alfonso               6             9    놀이  ...  [빨강색, 파랑색]        [심플]  6.0
#
# ...

# %%
def get_yday(bdstr: str) -> int:
  m, d = map(int, bdstr.split('-'))
  return date(2020, m, d).timetuple().tm_yday

# %%
chars['birthday_yday'] = chars['birthday'].apply(get_yday)

# %%
list(chars.columns)
# Out:
# ['name_ko',
#  'name_en',
#  'special',
#  'gender',
#  'gender_asia',
#  'species',
#  'birthday',
#  'birthday_month',
#  'birthday_day',
#  'hobby',
#  'personality',
#  'personality_subtype',
#  'colors',
#  'styles',
#  'tier',
#  'rank',
#  'catchphrase',
#  'favorite_saying',
#  'favorite_song',
#  'image_house',
#  'image_icon',
#  'image_photo',
#  'birthday_yday']

# %%
chars = chars[
  [
    'name_ko',
    'name_en',
    'special',
    'gender',
    'gender_asia',
    'species',
    'birthday',
    'birthday_month',
    'birthday_day',
    'birthday_yday',
    'hobby',
    'personality',
    'personality_subtype',
    'colors',
    'styles',
    'tier',
    'rank',
    'catchphrase',
    'favorite_saying',
    'favorite_song',
    'image_house',
    'image_icon',
    'image_photo',
 ]
]

# %%
chars.head()
# Out:
#         name_ko  name_en  special  gender gender_asia species birthday  \
# id
# admiral      일섭  Admiral    False    Male        Male       새    01-27
# agents       2호  Agent S    False  Female      Female     다람쥐    07-02
# agnes      아그네스    Agnes    False  Female      Female      돼지    04-21
# al           우락       Al    False    Male        Male     고릴라    10-18
# alfonso    알베르트  Alfonso    False    Male        Male      악어    06-09
#
#          birthday_month  birthday_day  birthday_yday  ...      styles tier  \
# id                                                    ...
# admiral               1            27             27  ...         [쿨]  6.0
# agents                7             2            184  ...   [심플, 액티브]  6.0
# agnes                 4            21            112  ...  [심플, 엘레강스]  4.0
# al                   10            18            292  ...       [액티브]  6.0
# alfonso               6             9            161  ...        [심플]  6.0
#
# ...

# %% [markdown]
# ## export

# %% [markdown]
# ### 일단 엑셀파일도 업데이트합니다.

# %%
chars.to_excel('./datasets/characters.xlsx', freeze_panes=(1, 2))

# %% [markdown]
# ### 다음은 `json`

# %%
chars['id'] = chars.index
# chars = chars.drop('id', axis=1)
# Out:
# C:\Users\movomo\AppData\Local\Temp\ipykernel_16120\3781580473.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chars['id'] = chars.index

# %%
chars.head()
# Out:
#         name_ko  name_en  special  gender gender_asia species birthday  \
# id
# admiral      일섭  Admiral    False    Male        Male       새    01-27
# agents       2호  Agent S    False  Female      Female     다람쥐    07-02
# agnes      아그네스    Agnes    False  Female      Female      돼지    04-21
# al           우락       Al    False    Male        Male     고릴라    10-18
# alfonso    알베르트  Alfonso    False    Male        Male      악어    06-09
#
#          birthday_month  birthday_day  birthday_yday  ...      styles tier  \
# id                                                    ...
# admiral               1            27             27  ...         [쿨]  6.0
# agents                7             2            184  ...   [심플, 액티브]  6.0
# agnes                 4            21            112  ...  [심플, 엘레강스]  4.0
# al                   10            18            292  ...       [액티브]  6.0
# alfonso               6             9            161  ...        [심플]  6.0
#
# ...

# %%
with open('./datasets/characters.json', 'w', encoding='utf-8') as j_out:
  json.dump(
    {index: row.dropna().to_dict() for index, row in chars.iterrows()},
    j_out,
  )
